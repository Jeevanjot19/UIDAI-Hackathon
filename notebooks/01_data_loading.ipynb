# %% [markdown]
# # 01 - Data Loading & Initial Exploration
# ## Aadhaar Societal Intelligence Project
#
# **Objective**: Load and merge all three UIDAI datasets (Enrolment, Demographic Updates, Biometric Updates) and perform initial data exploration.
#
# **Datasets**:
# 1. Aadhaar Enrolment Dataset
# 2. Aadhaar Demographic Update Dataset
# 3. Aadhaar Biometric Update Dataset

# %%
# Import required libraries
import sys
import os

# Add parent directory to path
sys.path.append('../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# Set visualization style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("Set2")

print("✓ Libraries imported successfully")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")

# %% [markdown]
# ## Step 1: Initialize Data Loader
